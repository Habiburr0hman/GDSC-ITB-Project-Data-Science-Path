# %%
# Mengimpor library yang diperlukan
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
 
# Inisialisasi CNN
MesinKlasifikasi = Sequential()
 
# Langkah 1 - Convolution
MesinKlasifikasi.add(Conv2D(filters = 32, kernel_size=(3, 3), input_shape = (128, 128, 3), activation = 'relu'))
 
# Langkah 2 - Pooling
MesinKlasifikasi.add(MaxPooling2D(pool_size = (2, 2)))
 
# Menambah convolutional layer
# MesinKlasifikasi.add(Conv2D(32, (3, 3), activation = 'relu'))
# MesinKlasifikasi.add(MaxPooling2D(pool_size = (2, 2)))
 
# Langkah 3 - Flattening
MesinKlasifikasi.add(Flatten())
 
# Langkah 4 - Full connection
MesinKlasifikasi.add(Dense(units = 32, activation = 'relu'))
MesinKlasifikasi.add(Dense(units = 32, activation = 'relu'))
MesinKlasifikasi.add(Dense(units = 1, activation = 'sigmoid'))
 
# Menjalankan CNN
MesinKlasifikasi.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
 
# Menjalankan CNN ke training dan test set
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
 
test_datagen = ImageDataGenerator(rescale = 1./255)
 
training_set = train_datagen.flow_from_directory('CNN dataset/training_set',
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
 
test_set = test_datagen.flow_from_directory('CNN dataset/test_set',
                                            target_size = (128, 128),
                                            batch_size = 32,
                                            class_mode = 'binary')
 
MesinKlasifikasi.fit_generator(training_set,
                         steps_per_epoch = 8000/160,
                         epochs = 50,
                         validation_data = test_set,
                         validation_steps = 2000/40)
# Out:
# Found 8011 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Epoch 1/50
# 50/50 [==============================] - 40s 794ms/step - loss: 0.9621 - accuracy: 0.5079 - val_loss: 0.6842 - val_accuracy: 0.5231
# Epoch 2/50
# 50/50 [==============================] - 25s 493ms/step - loss: 0.6621 - accuracy: 0.6029 - val_loss: 0.6246 - val_accuracy: 0.6506
# Epoch 3/50
# 50/50 [==============================] - 22s 431ms/step - loss: 0.6178 - accuracy: 0.6600 - val_loss: 0.6626 - val_accuracy: 0.6062
# Epoch 4/50
# 50/50 [==============================] - 20s 405ms/step - loss: 0.6266 - accuracy: 0.6394 - val_loss: 0.5786 - val_accuracy: 0.6994
# Epoch 5/50
# 50/50 [==============================] - 20s 393ms/step - loss: 0.5887 - accuracy: 0.6751 - val_loss: 0.5606 - val_accuracy: 0.7175
# Epoch 6/50
# 50/50 [==============================] - 20s 395ms/step - loss: 0.5770 - accuracy: 0.6988 - val_loss: 0.5634 - val_accuracy: 0.7025
# Epoch 7/50
# ...

# %%
#MesinKlasifikasi.save("CNN dataset/model.h5")

# %%
#MesinKlasifikasi.save_weights("CNN dataset/weight.h5")

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
def predict(file):
    x = image.load_img(file, target_size=(128,128))
    x = image.img_to_array(x)
    x = np.expand_dims(x, axis=0)
    array = MesinKlasifikasi.predict(x)
    result = array[0]
    if result == 0:
        print("kucing")
    else:
        print("anjing")

# %%
predict("CNN dataset/single_prediction/cat-or-dog.jpg")
